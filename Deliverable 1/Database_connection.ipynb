# %%
# Import dependencies
import pandas as pd
import csv
import os

from sqlalchemy import create_engine
from sqlalchemy.orm import scoped_session, sessionmaker
import psycopg2

import warnings
warnings.filterwarnings('ignore')

# %%
# Create the Database Engine
db_password = "Sam123"
conn_string = f"postgresql://Sam:{db_password}@localhost:5432/Portland_Housing_Prices"
db = create_engine(conn_string)
conn = db.connect()

# Check to make sure all the columns & rows were imported correctly to PostgreSQL
check = pd.read_sql_query("SELECT * FROM merged_table", con=conn)
check


#create_engine("postgresql://login:password@localhost:5432/flight")
# Out:
# -------------------------------------------------------------------------
# OperationalError                        Traceback (most recent call last)
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3255         try:
# -> 3256             return fn()
#    3257         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ...

# %%
# Close the connection to the database
conn.close()

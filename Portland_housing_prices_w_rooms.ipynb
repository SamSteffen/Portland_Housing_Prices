# %%
# import dependencies
import pandas as pd
import os
import csv
from datetime import datetime
import datetime as dt
import time

# %%
# read in the data as a df
file_path = 'C:/Users/ssteffen/desktop/sam/Vanderbilt Boot Camp/MyRepo/Module 20_Final/Final Project/Resources\portland_housing.csv'

raw_df = pd.read_csv(file_path)
raw_df.head()
# Out:
# C:\Users\ssteffen\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (20,50,161,200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         abbreviatedAddress address/city  address/zipcode  bathrooms  bedrooms  \
# 0  2860 NE Blossom Hill Rd     Fairview            97024        3.0       3.0
# 1    20386 NE Mackenzie Ln     Fairview            97024        3.0       3.0
# 2          1121 SW 10th Dr      Gresham            97080        3.0       4.0
# 3       19309 NE Glisan St     Portland            97230        1.0       3.0
# 4         25-65 NW 20th St      Gresham            97030        3.0       6.0
#
#                          brokerageName      dateSold  daysOnZillow  \
# 0                                  NaN  1.621560e+12          25.0
# 1  Harcourts Real Estate Network Group  1.619140e+12          53.0
# ...

# %%
# Explore data columns
columns = raw_df.columns.tolist()
columns
# Out:
# ['abbreviatedAddress',
#  'address/city',
#  'address/zipcode',
#  'bathrooms',
#  'bedrooms',
#  'brokerageName',
#  'dateSold',
#  'daysOnZillow',
#  'description',
#  'favoriteCount',
#  'homeStatus',
#  'homeType',
#  'lastSoldPrice',
#  'latitude',
#  'livingArea',
#  'longitude',
#  'lotSize',
#  'pageViewCount',
#  'postingContact/name',
#  'price',
#  'priceHistory/0/attributeSource/infoString1',
#  'priceHistory/0/attributeSource/infoString2',
#  'priceHistory/0/attributeSource/infoString3',
#  'priceHistory/0/buyerAgent/name',
#  'priceHistory/0/buyerAgent/photo/url',
#  'priceHistory/0/buyerAgent/profileUrl',
#  'priceHistory/0/date',
#  'priceHistory/0/event',
#  'priceHistory/0/postingIsRental',
#  'priceHistory/0/price',
#  'priceHistory/0/priceChangeRate',
#  'priceHistory/0/pricePerSquareFoot',
#  'priceHistory/0/sellerAgent/name',
#  'priceHistory/0/sellerAgent/photo/url',
#  'priceHistory/0/sellerAgent/profileUrl',
#  'priceHistory/0/showCountyLink',
# ...

# %%
#call a new df with only relevant data columns
df = raw_df[[
     'abbreviatedAddress',
     'address/city',
     'address/zipcode',
     'bathrooms',
     'bedrooms',
     'dateSold',
     'daysOnZillow',
     'latitude',
     'longitude',
     'lotSize',
     'price',
     'propertyTaxRate',
     'rentZestimate',
     'taxAssessedValue',
     'taxAssessedYear',
     'zestimate',
]]

df
# Out:
#             abbreviatedAddress address/city  address/zipcode  bathrooms  \
# 0      2860 NE Blossom Hill Rd     Fairview            97024        3.0
# 1        20386 NE Mackenzie Ln     Fairview            97024        3.0
# 2              1121 SW 10th Dr      Gresham            97080        3.0
# 3           19309 NE Glisan St     Portland            97230        1.0
# 4             25-65 NW 20th St      Gresham            97030        3.0
# 5              1518 SE 12th St      Gresham            97080        2.0
# 6        110 NW Willowbrook Ct      Gresham            97030        2.0
# 7         4252 SW Lillyben Ave      Gresham            97080        2.0
# 8          1671 SE Liberty Ave      Gresham            97080        3.0
# 9          3569 SW Mckinley St      Gresham            97080        3.0
# 10          520 SE Juniper Ave      Gresham            97080        3.0
# 11        4230 SW Lillyben Ave      Gresham            97080        4.0
# ...

# %%
#drop NaN values
df_clean = df.dropna(how="any")
df_clean
# Out:
#             abbreviatedAddress address/city  address/zipcode  bathrooms  \
# 0      2860 NE Blossom Hill Rd     Fairview            97024        3.0
# 2              1121 SW 10th Dr      Gresham            97080        3.0
# 5              1518 SE 12th St      Gresham            97080        2.0
# 6        110 NW Willowbrook Ct      Gresham            97030        2.0
# 8          1671 SE Liberty Ave      Gresham            97080        3.0
# 9          3569 SW Mckinley St      Gresham            97080        3.0
# 10          520 SE Juniper Ave      Gresham            97080        3.0
# 12            19830 SE Pine St     Portland            97233        2.0
# 13              705 NE 18th Ct      Gresham            97030        1.0
# 15             2349 SW 19th Ct      Gresham            97080        3.0
# 16           18851 NE Davis St     Portland            97230        1.0
# 17          16621 NE Halsey St     Portland            97230        2.0
# ...

# %%
df_clean.dtypes
# Out:
# abbreviatedAddress     object
# address/city           object
# address/zipcode         int64
# bathrooms             float64
# bedrooms              float64
# dateSold              float64
# daysOnZillow          float64
# latitude              float64
# longitude             float64
# lotSize               float64
# price                   int64
# propertyTaxRate       float64
# rentZestimate         float64
# taxAssessedValue      float64
# taxAssessedYear       float64
# zestimate             float64
# dtype: object

# %%
# convert the date type columns to datetype data in new columns, then drop the old columns
df_clean['Date_sold'] = pd.to_datetime(df_clean['dateSold'], unit='ms').dt.date
df_clean['bathrooms'] = df_clean['bathrooms'].astype(int) 
df_clean['bedrooms'] = df_clean['bedrooms'].astype(int)
df_clean['lotSize'] = df_clean['lotSize'].astype(int)
df_clean['daysOnZillow'] = df_clean['daysOnZillow'].astype(int)
df_clean['taxAssessedYear'] = df_clean['taxAssessedYear'].astype(int)

df_clean = df_clean.drop(columns=[
    'dateSold'])

df_clean
# Out:
# C:\Users\ssteffen\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\ssteffen\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\ssteffen\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# reorder the columns in the desired output format
# df_clean.columns
df_clean = df_clean[[
    'abbreviatedAddress',
    'address/city', 
    'address/zipcode', 
    'latitude', 
    'longitude',
    'bathrooms',
    'bedrooms',
    'lotSize',
    'daysOnZillow',
    'Date_sold',
    'price', 
    'zestimate', 
    'rentZestimate',
    'propertyTaxRate', 
    'taxAssessedValue', 
    'taxAssessedYear', 
]]

df_clean.head()
# Out:
#         abbreviatedAddress address/city  address/zipcode   latitude  \
# 0  2860 NE Blossom Hill Rd     Fairview            97024  45.543571
# 2          1121 SW 10th Dr      Gresham            97080  45.488228
# 5          1518 SE 12th St      Gresham            97080  45.487991
# 6    110 NW Willowbrook Ct      Gresham            97030  45.498184
# 8      1671 SE Liberty Ave      Gresham            97080  45.485195
#
#     longitude  bathrooms  bedrooms  lotSize  daysOnZillow   Date_sold   price  \
# 0 -122.441765          3         3     1555            25  2021-05-21  315400
# 2 -122.444420          3         4     9583            11  2021-06-03  512000
# 5 -122.416184          2         3     7000            14  2021-06-01  404200
# 6 -122.451332          2         3     6969            25  2021-05-21  478200
# 8 -122.418839          3         3     5009            12  2021-05-12  419900
#
#    zestimate  rentZestimate  propertyTaxRate  taxAssessedValue  \
# ...

# %%
#drop duplicate rows, if any
df_clean = df_clean.drop_duplicates()
df_clean.count()
# Out:
# abbreviatedAddress    21168
# address/city          21168
# address/zipcode       21168
# latitude              21168
# longitude             21168
# bathrooms             21168
# bedrooms              21168
# lotSize               21168
# daysOnZillow          21168
# Date_sold             21168
# price                 21168
# zestimate             21168
# rentZestimate         21168
# propertyTaxRate       21168
# taxAssessedValue      21168
# taxAssessedYear       21168
# dtype: int64

# %%
# sort the data by date sold, beginning with the most recent
df_clean = df_clean.sort_values(by='Date_sold', ascending=False)
df_clean = df_clean.reset_index(drop=True)
df_clean
# Out:
#                 abbreviatedAddress  address/city  address/zipcode   latitude  \
# 0           21832 NE Heartwood Cir      Fairview            97024  45.543423
# 1              8317 SE Christen Ct     Gladstone            97027  45.394726
# 2                 5614 NE 18th Ave      Portland            97211  45.563541
# 3             336 SW Wonderview Dr       Gresham            97080  45.494404
# 4                1738 NE 150th Ave      Portland            97230  45.535900
# 5                4261 SW Rodlun Rd       Gresham            97080  45.465721
# 6                  1339 SW Kari Ln      Portland            97219  45.448067
# 7              2303 NW Stanley Ave       Gresham            97030  45.512840
# 8             5914 N Borthwick Ave      Portland            97217  45.565826
# 9                1035 SE 225th Ave       Gresham            97030  45.514957
# 10           17335 SW Noble Fir Ct      Sherwood            97140  45.359512
# ...

# %%
# find the bottom of the date range of the dataset
df_clean['Date_sold'].min()
# Out:
# datetime.date(2020, 6, 12)

# %%
# find the number of rows of usable data in the dataset
df_clean.describe()
# Out:
#        address/zipcode      latitude     longitude     bathrooms  \
# count     21168.000000  21168.000000  21168.000000  21168.000000
# mean      97145.395125     45.474597   -122.686402      2.558673
# std          86.430397      0.066103      0.145093      0.963380
# min       97003.000000     45.260349   -123.074242      0.000000
# 25%       97062.000000     45.428975   -122.806108      2.000000
# 50%       97202.000000     45.484182   -122.671970      3.000000
# 75%       97221.000000     45.524388   -122.592743      3.000000
# max       97267.000000     45.646896   -122.280975     10.000000
#
#            bedrooms       lotSize  daysOnZillow         price     zestimate  \
# count  21168.000000  2.116800e+04  21168.000000  2.116800e+04  2.116800e+04
# mean       3.438728  2.591428e+04    187.777447  5.997890e+05  6.594082e+05
# std        0.924630  1.436771e+06    112.958550  3.777884e+05  3.500986e+05
# ...

# %%
# export the df to a csv without an index
df_clean.to_csv('C:/Users/ssteffen/desktop/sam/Vanderbilt Boot Camp/MyRepo/Module 20_Final/Final Project/Resources/Portland_data_cleaned_w_roomdata.csv', index=False)
